# %%
import numpy as np
import pandas as pd

#
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn import metrics

# %%
# Load numpy array
data = np.load('./data/dat_pca_50_target.npz')
data.files
# Out:
# ['arr_0', 'arr_1']

# %%
data.allow_pickle = True
X = data['arr_0'] # pca_with 50 components
y = data['arr_1'] # target variable

# %%
y
# Out:
# array(['female', 'female', 'female', ..., 'male', 'male', 'male'],
#       dtype=object)

# %% [markdown]
# ### split the data into train and test

# %%
x_train, x_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, stratify = y)

print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (3646, 50) (912, 50) (3646,) (912,)

# %% [markdown]
# ### Training Machine Learning Model

# %%
model_svc = SVC(probability=True)
param_grid = {'C':[0.5,1,0,20,30,50],
              'kernel':['rbf','poly'],
              'gamma':[0.1,0.05,0.0,0.001,0.002,0.005],
              'coef0':[0,1]}

# %%
model_grid = GridSearchCV(model_svc, param_grid = param_grid,
                         scoring='accuracy',cv=3,verbose=2)

# %%
model_grid.fit(x_train,y_train)
# Out:
# Fitting 3 folds for each of 144 candidates, totalling 432 fits
# [CV] END ..............C=0.5, coef0=0, gamma=0.0, kernel=rbf; total time=   2.0s
# [CV] END ..............C=0.5, coef0=0, gamma=0.0, kernel=rbf; total time=   1.9s
# [CV] END ..............C=0.5, coef0=0, gamma=0.0, kernel=rbf; total time=   1.9s
# [CV] END .............C=0.5, coef0=0, gamma=0.0, kernel=poly; total time=   1.3s
# [CV] END .............C=0.5, coef0=0, gamma=0.0, kernel=poly; total time=   1.3s
# [CV] END .............C=0.5, coef0=0, gamma=0.0, kernel=poly; total time=   1.3s
# [CV] END .............C=0.5, coef0=0, gamma=0.05, kernel=rbf; total time=   2.4s
# [CV] END .............C=0.5, coef0=0, gamma=0.05, kernel=rbf; total time=   2.5s
# [CV] END .............C=0.5, coef0=0, gamma=0.05, kernel=rbf; total time=   2.7s
# [CV] END ............C=0.5, coef0=0, gamma=0.05, kernel=poly; total time=   1.8s
# [CV] END ............C=0.5, coef0=0, gamma=0.05, kernel=poly; total time=   1.8s
# ...

# %%
model_grid.best_params_
# Out:
# {'C': 1, 'coef0': 0, 'gamma': 0.05, 'kernel': 'rbf'}

# %%
model_final = model_grid.best_estimator_

# %%
model_final.get_params()
# Out:
# {'C': 1,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 0.05,
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'probability': True,
#  'random_state': None,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %% [markdown]
# ## Model Evaluation
# -  classification Report
# -- precision, Recall, F1-score
# -  Kappa Score
# -- -ve(Worst model)
# -- 0 to 0.5(bad Model)
# -- 0.5 to 0.7(Good Model)
# -- 0.7 to 0.9(Excellent Model)
# -- 0.9 to 1(Perfect Model)
# -  AUC
# -- Less than 0.5 (Worst Model)
# -- 0.5 to 0.6 (Bad Model)
# -- 0.6 to 0.8 (Good Model)
# -- 0.8 to 0.9 (Excellent Model)
# -- 0.9 to 1   (Perfect Model)

# %%
y_pred = model_final.predict(x_test)

# %%
y_pred
# Out:
# array(['female', 'female', 'male', 'female', 'female', 'female', 'female',
#        'female', 'female', 'male', 'female', 'female', 'female', 'female',
#        'female', 'male', 'female', 'female', 'female', 'male', 'female',
#        'male', 'male', 'female', 'female', 'female', 'female', 'female',
#        'male', 'male', 'male', 'male', 'male', 'female', 'male', 'male',
#        'female', 'male', 'female', 'male', 'male', 'female', 'female',
#        'female', 'female', 'female', 'female', 'male', 'female', 'female',
#        'female', 'female', 'female', 'female', 'female', 'male', 'male',
#        'female', 'female', 'female', 'female', 'female', 'male', 'male',
#        'male', 'female', 'female', 'male', 'female', 'male', 'male',
#        'female', 'female', 'female', 'female', 'female', 'female', 'male',
#        'female', 'male', 'female', 'female', 'female', 'male', 'male',
#        'male', 'male', 'female', 'male', 'female', 'male', 'female',
# ...

# %% [markdown]
# ### **classification Report**

# %%
cr = metrics.classification_report(y_test,y_pred,output_dict = True)
pd.DataFrame(cr).T
# Out:
#               precision    recall  f1-score     support
# female         0.799599  0.806061  0.802817  495.000000
# male           0.767554  0.760192  0.763855  417.000000
# accuracy       0.785088  0.785088  0.785088    0.785088
# macro avg      0.783577  0.783126  0.783336  912.000000
# weighted avg   0.784947  0.785088  0.785002  912.000000

# %% [markdown]
# ### Kappa Score

# %%
metrics.cohen_kappa_score(y_test,y_pred)
# Out:
# 0.5666807266592003

# %% [markdown]
# ### AUC Score

# %%
metrics.roc_auc_score(np.where(y_test=='male',1,0),np.where(y_pred=='male',1,0))
# Out:
# 0.7831262262916939

# %% [markdown]
# ### Save Face Recognition Model

# %%
import pickle

# %%
pickle.dump(model_final,open('./model/model_svm.pickle',mode='wb'))
